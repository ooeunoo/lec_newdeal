# %%
import matplotlib.pyplot as plt # pip install matplotlib

# %%
X = [1, 2, 3, 4 ,5]
Y = [1, 2.2, 1.2, 4.4, 0.2]

plt.plot(X, Y)

# %%
X = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
Y = [15.6, 14.2, 16.3, 18.2, 17.1, 15.0, 19.2] # 한국
Y2 = [23.4, 23.2, 21.5, 29.1, 22.3, 24.0, 26.9] # 미국

plt.rc('font', family='Malgun Gothic') ## 한글 적용

# plt.plot(X,Y, X, Y2)
plt.plot(X, Y, label = "한글", linestyle="dashed")
plt.plot(X, Y2, label = "미국")

plt.legend(loc="lower right")

plt.xlabel("day")
plt.ylabel("temperture")

plt.title("Temperature of Cities")
# Out:
# Text(0.5, 1.0, 'Temperature of Cities')

# %%
X  = [ 1,2,3,4]
Y = [10, 20, 30, 40]

plt.plot(X, Y, "sm") 
plt.grid(axis="y", color='b', linestyle='-', linewidth=1)

# %%
import numpy as np

# %%
X = np.arange(2, 20, 2)

plt.plot(X, X**2)

plt.xticks([2, 6, 10, 14, 18])
plt.yticks([0, 100, 200, 300], labels=["비정상", "정상", "경고", "위험"])
# Out:
# ([<matplotlib.axis.YTick at 0x11862420990>,
#   <matplotlib.axis.YTick at 0x118623b5b10>,
#   <matplotlib.axis.YTick at 0x1186242e790>,
#   <matplotlib.axis.YTick at 0x11862455950>],
#  [Text(0, 0, '비정상'),
#   Text(0, 100, '정상'),
#   Text(0, 200, '경고'),
#   Text(0, 300, '위험')])

# %%
X = [1,2,3]
Y = [100, 200, 300]

plt.bar(X, Y, color="red")
# Out:
# <BarContainer object of 3 artists>

# %%
X = [1,2,3]
Y = [100, 200, 300]

plt.barh(X, Y, color="red")
# Out:
# <BarContainer object of 3 artists>

# %%
ratio = [20, 10, 70]
labels = ["탄수화물", "단백질", "지방"]
plt.rc('font', family='Malgun Gothic') ## 한글 적용

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1186456a450>,
#   <matplotlib.patches.Wedge at 0x1186456b3d0>,
#   <matplotlib.patches.Wedge at 0x11864578490>],
#  [Text(0.8899186877588753, 0.6465637858537406, '탄수화물'),
#   Text(-2.5747358111484753e-08, 1.0999999999999999, '단백질'),
#   Text(-0.646563785853741, -0.889918687758875, '지방')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.0%'),
#   Text(-1.4044013515355319e-08, 0.5999999999999999, '10.0%'),
#   Text(-0.3526711559202223, -0.48541019332302265, '70.0%')])

# %%
weights = [79.8, 92.8, 70.2, 67.5]
heights = [1.78, 1.62, 1.82, 1.70]
students = ["철수", "영희", "민지", "민수"]
# bmi = weight / height ** 2
# 18.5 저체중
# 22.9 정상
# 24.9 과체중
# 30.0 비만

import numpy as np

np_weights = np.array(weights)
np_heights = np.array(heights)
bmis = np_weights / np_heights ** 2

plt.bar(students, bmis)
plt.yticks([18.5, 22.9, 24.9, 30.0], labels=["저체중", "정상"," 과체중", "비만"])
# Out:
# ([<matplotlib.axis.YTick at 0x118646b6310>,
#   <matplotlib.axis.YTick at 0x118646d0490>,
#   <matplotlib.axis.YTick at 0x1186461add0>,
#   <matplotlib.axis.YTick at 0x118646b6690>],
#  [Text(0, 18.5, '저체중'),
#   Text(0, 22.9, '정상'),
#   Text(0, 24.9, ' 과체중'),
#   Text(0, 30.0, '비만')])
